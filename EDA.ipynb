# %% [markdown]
# EDA - 1
#
# Bike Details Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('BIKE DETAILS.csv')

# %%
df.head()
# Out:
#                                   name  selling_price  year seller_type  \
# 0            Royal Enfield Classic 350         175000  2019  Individual
# 1                            Honda Dio          45000  2017  Individual
# 2  Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3    Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                Yamaha SZ [2013-2014]          20000  2011  Individual
#
#        owner  km_driven  ex_showroom_price
# 0  1st owner        350                NaN
# 1  1st owner       5650                NaN
# 2  1st owner      12000           148114.0
# 3  1st owner      23000            89643.0
# 4  2nd owner      21000                NaN

# %%
df.columns
# Out:
# Index(['name', 'selling_price', 'year', 'seller_type', 'owner', 'km_driven',
#        'ex_showroom_price'],
#       dtype='object')

# %%
df.shape
# Out:
# (1061, 7)

# %%
df.dtypes
# Out:
# name                  object
# selling_price          int64
# year                   int64
# seller_type           object
# owner                 object
# km_driven              int64
# ex_showroom_price    float64
# dtype: object

# %%
df.selling_price.unique()
# Out:
# array([175000,  45000, 150000,  65000,  20000,  18000,  78500, 180000,
#         30000,  50000,  35000,  28000,  80000, 365000, 185000,  25000,
#         40000, 120000,  15000,  26000,  32000, 110000,  42000,  21000,
#         55000,  38000,  43000,  62000,  60000,  90000, 125000,  85000,
#         29900,  70000,  48000,  34000, 165000,  29500,  95000,   7500,
#        160000, 140000,  22000,  22989,  24999,  75000,  17500,  57000,
#         83900, 135000, 299000, 750000, 190000, 130000,  54786,  72000,
#        100000, 138000, 170000, 123000,  23000,  41000,  47999,  36999,
#         12000,  27000,  10000,  56000,  58000,  87000, 145000,   9000,
#         14000,  17000, 210000,  54000, 260000,  98000, 200000, 195000,
#        270000, 425000, 760000,  37000, 330000, 162000, 285000,  69000,
#        300000,  26500,  78000,   8000,  39000,  36000,  16000,  83299,
#         14700,  19000,  14900,  24000,  24700,  52000,  47000, 105000,
# ...

# %%
df.ex_showroom_price.unique()
# Out:
# array([     nan,  148114.,   89643.,   53857.,   87719.,   60122.,
#          78712.,   47255.,   95955.,  351680.,   58314.,  117926.,
#         132680.,   44389.,   53900.,   56147.,   84751.,   61600.,
#          79432.,   78350.,   71049.,   57557.,  202310.,   71150.,
#          56750.,   84042.,   69750.,   59844.,   42859.,   73413.,
#          49900.,   59422.,   57549.,   51994.,   80350.,   54605.,
#          88161.,   78513.,   50098.,  195500.,   92074.,  164004.,
#          74295.,   49642.,   51112.,   53751.,   50267.,   61653.,
#          70851.,   53079.,  133680.,  181445.,   65626.,   58438.,
#          61118.,   75936.,  180525.,   87543.,   80435.,   85011.,
#        1278000.,  155740.,  202127.,   86744.,  156304.,   84246.,
#          49521.,   64589.,   69983.,   54299.,   72303.,   65800.,
#          58757.,   47032.,   79233.,  118997.,   52949.,   64071.,
#          61545.,  168482.,  163331.,   59095.,   75502.,   52271.,
# ...

# %%
df['ex_showroom_price'] = df['ex_showroom_price'].fillna(0)

# %%
df['ex_showroom_price'] = df['ex_showroom_price'].astype('int')

df['ex_showroom_price'].dtype
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# name                 object
# selling_price         int64
# year                  int64
# seller_type          object
# owner                object
# km_driven             int64
# ex_showroom_price     int64
# dtype: object

# %% [markdown]
# *ANSWERS*

# %% [markdown]
# 1. What is the range of selling prices in the dataset ?

# %%
range_value = df['selling_price'].max() - df['selling_price'].min()
print(f'The range of selling price is : {range_value} ')
# Out:
# The range of selling price is : 755000

# %% [markdown]
# 2.  What is the median selling price for bikes in the dataset ?

# %%
median_value = df['selling_price'].median()
print(f'The median selling price for bikes is {median_value}')
# Out:
# The median selling price for bikes is 45000.0

# %% [markdown]
# 3.  What is the most common seller type ?

# %%
common_seller_type = df['seller_type'].value_counts().idxmax()
print(f' The most common seller type is {common_seller_type}')
# Out:
#  The most common seller type is Individual

# %% [markdown]
# 4. How many bikes have driven more than 50,000 kilometers

# %%
num_of_bikes = (df['km_driven']>50000).sum()
print(f'The number of bikes which have driven more than 50,000 kilometers are {num_of_bikes}')
# Out:
# The number of bikes which have driven more than 50,000 kilometers are 170

# %% [markdown]
# 5. What is the average km_driven value for each ownership type

# %%
avg_km_driven = round(df.groupby('owner')['km_driven'].mean(),1)
print(avg_km_driven)
# Out:
# owner
# 1st owner     32816.6
# 2nd owner     39289.0
# 3rd owner     33292.2
# 4th owner    311500.0
# Name: km_driven, dtype: float64

# %% [markdown]
# 6. What proportion of bikes are from the year 2015 or older

# %%
prop_of_bikes = round((df['year'] <=2015).mean(),2)
print(f'Theproportion of bikes are from the year 2015 or older is  {prop_of_bikes}')
# Out:
# Theproportion of bikes are from the year 2015 or older is  0.57

# %% [markdown]
# 7. What is the trend of missing values across the dataset

# %%
missing_values = (df.isna().sum()/len(df)) * 100
print(missing_values)
# Out:
# name                 0.0
# selling_price        0.0
# year                 0.0
# seller_type          0.0
# owner                0.0
# km_driven            0.0
# ex_showroom_price    0.0
# dtype: float64

# %% [markdown]
# 8. What is the highest ex_showroom_price recorded, and for which bike

# %%
max_showroom_price = df['ex_showroom_price'].max()
bike_with_max_price = df[df['ex_showroom_price'] == max_showroom_price]
bike_with_max_price['name']
# Out:
# 134    Harley-Davidson Street Bob
# Name: name, dtype: object

# %% [markdown]
# 9. What is the total number of bikes listed by each seller type

# %%
total_bikes = df.groupby('seller_type')['name'].count()
total_bikes
# Out:
# seller_type
# Dealer           6
# Individual    1055
# Name: name, dtype: int64

# %% [markdown]
# 10. What is the relationship between selling_price and km_driven for first-owner bikes

# %%
first_owner_bikes = df[df['owner'] =='1st owner']

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data = first_owner_bikes,x='selling_price',y='km_driven')
plt.title('Relationship between selling price and km driven')
plt.xlabel('selling price')
plt.ylabel('km driven')
plt.show()

# %% [markdown]
# 11. Identify and remove outliers in the km_driven column using the IQR method

# %%
Q1 = df['km_driven'].quantile(0.25)
Q3 = df['km_driven'].quantile(0.75)
IQR = Q3 - Q1
lower_bound =Q1 - 1.5 *IQR
upper_bound = Q3 + 1.5 * IQR

# %%
#identifying outliers
outliers =df[(df['km_driven'] <= lower_bound) | (df['km_driven'] >= upper_bound)]
outliers['km_driven']
# Out:
# 91      500000
# 93      130000
# 115     120000
# 135      90000
# 154      99000
# 184     100000
# 363     646000
# 470      95000
# 474      90000
# 477     585659
# 511     100000
# 535     100000
# 548     100000
# 575     340000
# 592     101000
# 598     120000
# 610     100000
# 630      98000
# 642     880000
# 668      93000
# 687     100000
# 695     100000
# 712     100000
# 714     240000
# 716     100000
# 726     100000
# 773      95000
# 782     100000
# 797     345000
# 830     100000
# 872      93000
# 877     450000
# 901     100000
# 903     127000
# 908      89000
# 930     100000
# 1039    213000
# 1056    500000
# 1060     92233
# Name: km_driven, dtype: int64

# %%
#removing outliers
outliers =df[(df['km_driven'] <= lower_bound) & (df['km_driven'] >= upper_bound)]
outliers['km_driven']
# Out:
# Series([], Name: km_driven, dtype: int64)

# %% [markdown]
# 12.  Perform a bivariate analysis to visualize the relationship between year and selling_price

# %%
plt.figure(figsize = (8,5))
sns.boxplot(data = df,x= 'year',y = 'selling_price')
plt.title('selling price on different years')
plt.xticks(rotation =45)
plt.xlabel('year')
plt.ylabel('selling price')
plt.show()

# %% [markdown]
# 13. What is the average depreciation in selling price based on the bike's age (current year - manufacturing
# year)

# %%
current_year = 2025
df['age'] = current_year - df['year']
avg_price = df.groupby('age')['selling_price'].mean()
avg_price
# Out:
# age
# 5     183333.333333
# 6     119689.511628
# 7      87660.374046
# 8      78894.736842
# 9      58469.018692
# 10     56500.000000
# 11     48668.131868
# 12     51136.986301
# 13     35748.400000
# 14     35655.721311
# 15     31793.333333
# 16     22267.857143
# 17     34289.285714
# 18     24927.586207
# 19     23380.000000
# 20     16978.571429
# 21     15100.000000
# 22      8000.000000
# 23     20666.666667
# 24     40000.000000
# 25     20833.333333
# 26     15000.000000
# 27     28333.333333
# 28     17500.000000
# 30    150000.000000
# 32    130000.000000
# 34      6000.000000
# 37     20000.000000
# Name: selling_price, dtype: float64

# %% [markdown]
# 14.  Which bike names are priced significantly above the average price for their manufacturing year ?

# %%
df['year_avg_price'] = df.groupby('year')['selling_price'].transform('mean')
df['is_above_avg'] = df['selling_price'] > df['year_avg_price']
df['is_above_avg']
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 1056    False
# 1057    False
# 1058    False
# 1059    False
# 1060    False
# Name: is_above_avg, Length: 1061, dtype: bool

# %% [markdown]
# 15.  Develop a correlation matrix for numeric columns and visualize it using a heatmap.

# %%
corr_matrix = df.select_dtypes(include= 'number').corr()
corr_matrix
sns.heatmap(corr_matrix,annot = True,cmap = 'coolwarm')
plt.show()

# %% [markdown]
# EDA - 2
#
# Car Sale.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df2 = pd.read_csv('Car Sale.csv')

# %%
df2.columns
# Out:
# Index(['Car_id', 'Date', 'Customer Name', 'Gender', 'Annual Income',
#        'Dealer_Name', 'Company', 'Model', 'Engine', 'Transmission', 'Color',
#        'Price ($)', 'Dealer_No ', 'Body Style', 'Phone', 'Dealer_Region'],
#       dtype='object')

# %% [markdown]
# ANSWERS

# %%
df2.rename(columns ={'Dealer_No ':'Dealer_no',
'Price ($)': 'Price'}, inplace = True)

# %% [markdown]
# 1. What is the average selling price of cars for each dealer, and how does it compare across different dealers

# %%
avg_selling_price = df2.groupby('Dealer_no')['Price'].mean().reset_index()
avg_selling_price.columns =['Dealer_No', 'avg_selling_price']
avg_selling_price
# Out:
#     Dealer_No  avg_selling_price
# 0  06457-3834       27771.614943
# 1  38701-8047       28208.618455
# 2  53546-9427       28009.712038
# 3  60504-7114       28134.025879
# 4  78758-7841       28272.412204
# 5  85257-3102       28259.141059
# 6  99301-3882       27920.853768

# %% [markdown]
# 2. Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing
# trends

# %%
price_variation = df2.groupby('Company')['Price'].std().reset_index()
price_variation.columns = ['Company','price_variation']
price_variation.sort_values(by = 'price_variation', ascending = False )
# Out:
#        Company  price_variation
# 15     Lincoln     19658.050211
# 24        Saab     19653.740089
# 4     Cadillac     19517.120220
# 21    Plymouth     19065.997338
# 14       Lexus     17852.923492
# 3        Buick     17142.232626
# 17     Mercury     16445.172195
# 19      Nissan     16214.264017
# 25      Saturn     15990.223671
# 8         Ford     15849.090227
# 16  Mercedes-B     15722.807459
# 20  Oldsmobile     15711.345857
# 27      Toyota     15367.131714
# 2          BMW     15065.578723
# 22     Pontiac     14348.963592
# 11    Infiniti     13696.332844
# 5    Chevrolet     13311.063223
# 29       Volvo     12933.790185
# 26      Subaru     12920.771620
# 1         Audi     12904.243867
# 28  Volkswagen     12527.124011
# 18  Mitsubishi     11671.343035
# 6     Chrysler     11583.286811
# 7        Dodge     11187.592085
# 9        Honda     11148.629062
# 12      Jaguar     10222.531533
# 13        Jeep      9459.834418
# 0        Acura      8183.046414
# ...

# %% [markdown]
# 3.  What is the distribution of car prices for each transmission type, and how do the interquartile ranges
# compare

# %%
transmission_type = df2.groupby('Transmission')['Price'].quantile(0.5)
transmission_type
# Out:
# Transmission
# Auto      24000.0
# Manual    22001.0
# Name: Price, dtype: float64

# %% [markdown]
# 4. What is the distribution of car prices across different regions ?

# %%
dist_of_car_price = df2.groupby('Dealer_Region')['Price'].mean()
dist_of_car_price
# Out:
# Dealer_Region
# Aurora        28334.626837
# Austin        28341.603628
# Greenville    28180.819054
# Janesville    27833.350955
# Middletown    27856.338875
# Pasco         28119.039923
# Scottsdale    27954.958928
# Name: Price, dtype: float64

# %% [markdown]
# 5. What is the distribution of cars based on body styles

# %%
dist_of_car_styles = df2.groupby('Company')['Body Style'].value_counts()
dist_of_car_styles
# Out:
# Company  Body Style
# Acura    SUV           372
#          Hatchback     269
#          Passenger      48
# Audi     SUV           348
#          Hardtop        70
#                       ...
# Volvo    Sedan         368
#          Hatchback     228
#          Hardtop       104
#          SUV            48
#          Passenger      41
# Name: count, Length: 126, dtype: int64

# %% [markdown]
# 6. How does the average selling price of cars vary by customer gender and annual income

# %%
avg_price_by_gender = df2.groupby('Gender')['Price'].mean()
print('The average selling price of cars by gender is ',round(avg_price_by_gender,2))
print( )
avg_price_by_income = df2.groupby('Annual Income')['Price'].mean()
print(' The average selling price of cars by Annual Income is ',round(avg_price_by_income,2))
# Out:
# The average selling price of cars by gender is  Gender
# Female    28277.27
# Male      28039.43
# Name: Price, dtype: float64
#
#  The average selling price of cars by Annual Income is  Annual Income
# 10080       22801.00
# 13500       27878.98
# 24000       61001.00
# 85000       43000.00
# 106000      46001.00
#               ...
# 6600000     39000.00
# 6800000     15000.00
# 7650000     21000.00
# 8000000     85000.00
# 11200000    26001.00
# Name: Price, Length: 2508, dtype: float64

# %% [markdown]
# 7. What is the distribution of car prices by region, and how does the number of cars sold vary by region ?

# %%
car_prices_by_region = df2.groupby('Dealer_Region')['Price'].std()
num_of_cars_sold = df2.groupby('Dealer_Region')['Price'].count()
print('the distribution of car prices by region', round(car_prices_by_region,2))
print('the number of cars sold vary by region ', num_of_cars_sold)
# Out:
# the distribution of car prices by region Dealer_Region
# Aurora        15026.21
# Austin        14903.88
# Greenville    15101.54
# Janesville    14345.00
# Middletown    14619.84
# Pasco         14659.32
# Scottsdale    14902.92
# Name: Price, dtype: float64
# the number of cars sold vary by region  Dealer_Region
# Aurora        3130
# Austin        4135
# Greenville    3128
# Janesville    3821
# Middletown    3128
# Pasco         3131
# Scottsdale    3433
# Name: Price, dtype: int64

# %% [markdown]
# 8.  How does the average car price differ between cars with different engine sizes

# %%
avg_car_price = df2.groupby('Engine')['Price'].mean()
avg_car_price
# Out:
# Engine
# DoubleÂ Overhead Camshaft    28248.525972
# Overhead Camshaft            27914.710631
# Name: Price, dtype: float64

# %% [markdown]
# 9. How do car prices vary based on the customer’s annual income bracket

# %%
car_prices_by_income = df2.groupby('Annual Income')['Price'].mean()
car_prices_by_income
# Out:
# Annual Income
# 10080       22801.000000
# 13500       27878.981415
# 24000       61001.000000
# 85000       43000.000000
# 106000      46001.000000
#                 ...
# 6600000     39000.000000
# 6800000     15000.000000
# 7650000     21000.000000
# 8000000     85000.000000
# 11200000    26001.000000
# Name: Price, Length: 2508, dtype: float64

# %% [markdown]
# 10. What are the top 5 car models with the highest number of sales, and how does their price distribution look ?

# %%
car_model_with_highest_sales = df2['Model'].value_counts().head(5)
top_models = car_model_with_highest_sales.index
top_models_prices =df2[df2['Model'].isin(top_models)]
top_models_prices
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 5      C_CND_000006    1/2/2022     Guadalupe    Male         850000
# 69     C_CND_000070    1/4/2022          Toby    Male          13500
# 91     C_CND_000092    1/5/2022      Mauricio    Male          13500
# 107    C_CND_000108    1/6/2022          Noel    Male        1362000
# 116    C_CND_000117    1/9/2022          Jake    Male         700000
# ...             ...         ...           ...     ...            ...
# 23868  C_CND_023869  12/30/2023        Youenn  Female          13500
# 23882  C_CND_023883  12/31/2023      Victoria    Male         501000
# 23884  C_CND_023885  12/31/2023        Winnie    Male         820500
# 23890  C_CND_023891  12/31/2023       Joaquin    Male        2450000
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
#
#                           Dealer_Name     Company       Model  \
# 5                       Classic Chevy  Mitsubishi    Diamante
# ...

# %% [markdown]
# 11. How does car price vary with engine size across different car colors, and which colors have the highest price
# variation ?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df2, x='Engine', y='Price', hue='Color')
plt.title('Car Price vs Engine Size Across Colors')
plt.xlabel('Engine Size')
plt.ylabel('Price')
plt.show()
print()
print('The color with thr highest price variation is :-')
highest_price_variation = df2.groupby('Color')['Price'].std().sort_values(ascending= False).head(1)
highest_price_variation
# Out:
# The color with thr highest price variation is :-
# Color
# Red    15519.360962
# Name: Price, dtype: float64

# %% [markdown]
# 12. Is there any seasonal trend in car sales based on the date of sale

# %%
df2['Month'] = df2['Date'].dt.month
df2['Month']
seasonal_trend = df2.groupby('Month')['Price'].count()
seasonal_trend
# Out:
# Month
# 1      790
# 2      735
# 3     1535
# 4     1655
# 5     1895
# 6     1715
# 7     1725
# 8     1705
# 9     3305
# 10    1830
# 11    3470
# 12    3546
# Name: Price, dtype: int64

# %% [markdown]
# 13. How does the car price distribution change when considering different combinations of body style and
# transmission type ?

# %%
car_price_distribution = df2.groupby(['Body Style', 'Transmission'])['Price'].describe()
car_price_distribution
# Out:
#                           count          mean           std      min      25%  \
# Body Style Transmission
# Hardtop    Auto          1408.0  31520.188210  13687.756740  12000.0  21001.0
#            Manual        1563.0  27016.943698  14072.501848  11000.0  17575.5
# Hatchback  Auto          3458.0  25910.544824  13144.014337   4200.0  18001.0
#            Manual        2670.0  28702.550562  16284.049616   1700.0  17000.0
# Passenger  Auto          2020.0  28915.835149  13946.481932   9000.0  19000.0
#            Manual        1925.0  28969.521039  18523.684163  10000.0  16001.0
# SUV        Auto          3086.0  27501.404407  13299.927913   1200.0  19000.0
#            Manual        3288.0  26079.019161  14621.526541   2200.0  17000.0
# Sedan      Auto          2599.0  29955.294344  14310.910860  12000.0  19000.0
#            Manual        1889.0  29664.271572  15440.056434  11000.0  19001.0
#
#                              50%      75%      max
# Body Style Transmission
# ...

# %% [markdown]
# 14. What is the correlation between car price, engine size, and annual income of customers, and how do these
# features interact ?

# %%
correlation = df2[['Price','Annual Income']].corr()
correlation
# Out:
#                   Price  Annual Income
# Price          1.000000       0.012065
# Annual Income  0.012065       1.000000

# %% [markdown]
# 15. How does the average car price vary across different car models and engine types?

# %%
avg_car_price = df2.groupby(['Model','Engine'])['Price'].mean()
avg_car_price
# Out:
# Model     Engine
# 3-Sep     DoubleÂ Overhead Camshaft    37986.380117
# 3000GT    DoubleÂ Overhead Camshaft    22764.326923
#           Overhead Camshaft            21770.659864
# 300M      DoubleÂ Overhead Camshaft    21394.888889
# 323i      DoubleÂ Overhead Camshaft    16744.632287
#                                            ...
# Windstar  Overhead Camshaft            17100.272727
# Wrangler  DoubleÂ Overhead Camshaft    21145.294737
#           Overhead Camshaft            18742.942029
# Xterra    DoubleÂ Overhead Camshaft    15940.459459
#           Overhead Camshaft            31072.500000
# Name: Price, Length: 261, dtype: float64

# %% [markdown]
# EDA - 3
#
# Amazon Sales Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('amazon.csv')
df.head(1)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
#
# ...

# %% [markdown]
# ANSWERS

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %% [markdown]
# 1. What is the average rating for each product category ?

# %%
df['rating'] = pd.to_numeric(df['rating'],errors= 'coerce')
avg_rating = df.groupby('category')['rating'].mean().reset_index()
avg_rating.columns = ['category','avg rating ']
avg_rating
# Out:
#                                               category  avg rating
# 0    Car&Motorbike|CarAccessories|InteriorAccessori...     3.800000
# 1    Computers&Accessories|Accessories&Peripherals|...     4.150000
# 2    Computers&Accessories|Accessories&Peripherals|...     3.500000
# 3    Computers&Accessories|Accessories&Peripherals|...     3.600000
# 4    Computers&Accessories|Accessories&Peripherals|...     4.050000
# ..                                                 ...          ...
# 206  OfficeProducts|OfficePaperProducts|Paper|Stati...     4.250000
# 207  OfficeProducts|OfficePaperProducts|Paper|Stati...     4.150000
# 208  OfficeProducts|OfficePaperProducts|Paper|Stati...     4.300000
# 209  OfficeProducts|OfficePaperProducts|Paper|Stati...     4.133333
# 210  Toys&Games|Arts&Crafts|Drawing&PaintingSupplie...     4.300000
#
# [211 rows x 2 columns]

# %% [markdown]
# 2. What are the top rating_count products by category ?

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df['rating_count'] = pd.to_numeric(df['rating_count'],errors= 'coerce')
top_rated_products = df.groupby('category')['rating_count'].nlargest(5)
top_rated_products
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                  1157   NaN
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                 695    NaN
#                                                                                                                         742    NaN
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                         906    NaN
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                      748    NaN
#                                                                                                                                 ..
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|RetractableBallpointPens  858    NaN
# ...

# %% [markdown]
# 3. What is the distribution of discounted prices vs. actual prices ?

# %%
df['discounted_price'] = pd.to_numeric(df['discounted_price'],errors = 'coerce')
df['actual_price'] = pd.to_numeric(df['actual_price'],errors = 'coerce')
df_clean = df.dropna(subset=['actual_price', 'discounted_price'])

plt.scatter(df['discounted_price'],df['actual_price'])
plt.title('Distributed Price VS Actual Price')
plt.xlabel('Distributed Price')
plt.ylabel('Actual Price')
plt.show()

# %% [markdown]
# 4. How does the average discount percentage vary across categories ?

# %%
df['discount_percentage'] = pd.to_numeric(df['discount_percentage'],errors= 'coerce')
avg_discount_percentage = df.groupby('category')['discount_percentage'].mean()
avg_discount_percentage
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                   NaN
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                  NaN
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                          NaN
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                       NaN
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                          NaN
#                                                                                                                           ..
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens       NaN
# ...

# %% [markdown]
# 5. What are the most popular product names ?

# %%
popular_products_name = df['product_name'].sort_values(ascending= False)
popular_products_name
# Out:
# 722     tizum HDMI to VGA Adapter Cable 1080P for Proj...
# 21      tizum HDMI to VGA Adapter Cable 1080P for Proj...
# 695     rts [2 Pack] Mini USB C Type C Adapter Plug, T...
# 439     realme narzo 50i (Mint Green, 2GB RAM+32GB Sto...
# 383     realme narzo 50 (Speed Blue, 4GB RAM+64GB Stor...
#                               ...
# 825     3M Post-it Sticky Note Cube, 200 Sheets (4 Col...
# 137     10k 8k 4k HDMI Cable, Certified 48Gbps 1ms Ult...
# 549     10WeRun Id-116 Bluetooth Smartwatch Wireless F...
# 1292    !!HANEUL!!1000 Watt/2000-Watt Room Heater!! Fa...
# 1158    !!1000 Watt/2000-Watt Room Heater!! Fan Heater...
# Name: product_name, Length: 1465, dtype: object

# %% [markdown]
# 6.  What are the most popular product keywords ?

# %%
popular_products_keywords = df['review_title'].sort_values(ascending= False)
popular_products_keywords
# Out:
# 1179    💥,Considering the price range, it’s a good one...
# 956     👎Disappointed 👎Review after 1 year 3 months of...
# 1158    👍,Good quality product and value for money. Re...
# 1370    👍,Good product,nice product,Satisfied,Value of...
# 1334    👍 nice,Lint removed instantly and effortlessly...
#                               ...
# 1133    5 star,LED light is not there.,Nice look,Bette...
# 1457    3,Sturdy and Works Flawlessly,Excellent 👍,Real...
# 824     12V2A RouterUPS,Decent Product,Product quality...
# 691     **UPDATE MARCH2021**Decent for a USB 2.0 Devic...
# 326     (after nearly one year use) Value for money TV...
# Name: review_title, Length: 1465, dtype: object

# %% [markdown]
# 7. What are the most popular product reviews

# %%
popular_products_reviews = df['review_content'].sort_values(ascending= False)
popular_products_reviews.head(5)
# Out:
# 1398    🔸Everything is nice,including design & functio...
# 235     👍,works very well and its still going great ev...
# 1370    👍,Good quality. Easy to use.,nice,Value for mo...
# 913     👌,1 bati , 5 bati,Voltage and performance is n...
# 102     এই রেপ্লিকা রিমোট সেট টা কাজ করছে। স্যামসাং এল...
# Name: review_content, dtype: object

# %% [markdown]
# 9.  What are the Top 5 categories based on the highest ratings ?

# %%
df['rating'] = pd.to_numeric(df['rating'],errors = 'coerce')
highest_rating = df.groupby('category').apply(lambda x: x.sort_values('rating',ascending = False))
highest_rating = highest_rating[['category', 'rating']].head(5)
highest_rating
# Out:
#                                                                                                   category  \
# category
# Car&Motorbike|CarAccessories|InteriorAccessorie... 1157  Car&Motorbike|CarAccessories|InteriorAccessori...
# Computers&Accessories|Accessories&Peripherals|A... 695   Computers&Accessories|Accessories&Peripherals|...
#                                                    742   Computers&Accessories|Accessories&Peripherals|...
# Computers&Accessories|Accessories&Peripherals|A... 906   Computers&Accessories|Accessories&Peripherals|...
# Computers&Accessories|Accessories&Peripherals|A... 748   Computers&Accessories|Accessories&Peripherals|...
#
#                                                          rating
# category
# Car&Motorbike|CarAccessories|InteriorAccessorie... 1157     3.8
# Computers&Accessories|Accessories&Peripherals|A... 695      4.3
#                                                    742      4.0
# ...

# %% [markdown]
# 10.  Identify any potential areas for improvement or optimization based on the data analysis
#
# -> Based on the data analysis, several potential areas for optimization were identified. The discounted_price column contains a large number of missing values, which may suggest that there are issues with data collection or product pricing transparency.
#
# ->Furthermore, the columns intended to hold numeric values were incorrectly stored as strings.

# %% [markdown]
# EDA - 4
#
# Spotify Data: Popular Hip-hop Artists and Tracks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('spotify.csv')

# %%
df.head(3)
# Out:
#   Artist                               Track Name  Popularity  Duration (ms)  \
# 0  Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92         319191
# 1  Drake                                One Dance          91         173986
# 2  Drake                       IDGAF (feat. Yeat)          90         260111
#
#                  Track ID
# 0  1yeB8MUNeLo9Ek1UEpsyz6
# 1  1zi7xx7UVEFkmKfv06H8x0
# 2  2YSzYUF3jWqb9YP9VXmpjE

# %%
df.shape
# Out:
# (440, 5)

# %%
df.dtypes
# Out:
# Artist           object
# Track Name       object
# Popularity        int64
# Duration (ms)     int64
# Track ID         object
# dtype: object

# %% [markdown]
# 1. Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do
# the needful

# %%
df.isnull().sum() #the dataframe doesn't have any duplicate rows
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
df[df.duplicated(subset = ['Track ID'])]
#No fully duplicated rows were found — i.e., each song/track appears only once, and each has a unique Track ID.
# Out:
#               Artist                                         Track Name  \
# 39      Travis Scott                             MELTDOWN (feat. Drake)
# 52      Travis Scott                   TELEKINESIS (feat. SZA & Future)
# 72         21 Savage                                            née-nah
# 73             Drake                      Jimmy Cooks (feat. 21 Savage)
# 76             Drake                                          Rich Flex
# 131            Drake               First Person Shooter (feat. J. Cole)
# 170     Metro Boomin            Trance (with Travis Scott & Young Thug)
# 182   D-Block Europe                                           Overseas
# 210      Post Malone      Sunflower - Spider-Man: Into the Spider-Verse
# 212     Metro Boomin  Annihilate (Spider-Man: Across the Spider-Vers...
# 222          Cardi B                    WAP (feat. Megan Thee Stallion)
# 224          Cardi B                 Bongos (feat. Megan Thee Stallion)
# ...

# %% [markdown]
# 2. What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram.

# %%
sns.histplot(data = df,x ='Popularity', kde=True)
plt.title('Distribution of Track Popularity')
plt.xlabel('Popularity')
plt.ylabel('Number of Tracks')
plt.show()

# %% [markdown]
# 3.Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot

# %%
sns.scatterplot(data = df,x = 'Popularity',y ='Duration (ms)',color = 'green')
plt.title('Relationship between the popularity and the duration of tracks')
plt.xlabel('Popularity')
plt.ylabel('Duration of tracks')
plt.show()

# %% [markdown]
# 4. Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using
# a countplot

# %%
top_artists = df['Artist'].value_counts().nlargest(10).index
sns.countplot(data =df[df['Artist'].isin(top_artists)],y = 'Artist',order=top_artists)
plt.title('Top 10 Most Frequent Artists')
plt.xlabel('Number of Tracks')
plt.ylabel('Artist')
plt.show()

#Drake has the highest number of tracks in the dataset

# %% [markdown]
# 5. What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each

# %%
least_popular_tracks =df.sort_values(by= 'Popularity',ascending= True).head(5)
least_popular_tracks[['Artist','Track Name']]
# Out:
#              Artist                     Track Name
# 207          Pressa  Attachments (feat. Coi Leray)
# 231   Justin Bieber                     Intentions
# 413  French Montana                Splash Brothers
# 435  French Montana                Splash Brothers
# 225        Lil Baby                  On Me - Remix

# %% [markdown]
# 6.  Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and
# display the average popularity for each artist

# %%
top_5_artists = df.groupby('Artist')['Popularity'].sum().sort_values(ascending=False).head(5)

top_5_artist_data = df[df['Artist'].isin(top_5_artists.index)]

average_popularity = top_5_artist_data.groupby('Artist')['Popularity'].mean()

most_popular_artist = average_popularity.idxmax()
highest_avg_popularity = average_popularity.max()

print("Artist with the highest average popularity:", most_popular_artist)
print("Highest average popularity:", highest_avg_popularity)
# Out:
# Artist with the highest average popularity: Travis Scott
# Highest average popularity: 87.0

# %% [markdown]
# 7. For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist

# %%
top_5_artists = df.groupby('Artist')['Popularity'].sum().sort_values(ascending=False).head(5)

top_5_artist_data = df[df['Artist'].isin(top_5_artists.index)]

most_popular_tracks = top_5_artist_data.loc[top_5_artist_data.groupby('Artist')['Popularity'].idxmax()]

for artist, track in most_popular_tracks[['Artist', 'Track Name']].iterrows():
    print(f"{track['Artist']}: {track['Track Name']}")
# Out:
# 21 Savage: redrum
# Drake: Rich Baby Daddy (feat. Sexyy Red & SZA)
# Eminem: Without Me
# Travis Scott: FE!N (feat. Playboi Carti)
# ¥$: CARNIVAL

# %% [markdown]
# 8. Visualize relationships between multiple numerical variables simultaneously using a pair plot

# %%
sns.pairplot(data=df)
plt.show()

# %% [markdown]
# 9. Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or
# violin plot

# %%
plt.figure(figsize=(10,22))
sns.boxplot(data=df, x ='Duration (ms)',y='Artist')
plt.show()

# %% [markdown]
# 10.  How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a
# violin plot.

# %%
plt.figure(figsize=(10,22))
sns.violinplot(data=df, x='Popularity',y = 'Artist')
plt.show()
